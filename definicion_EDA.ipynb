# %% [markdown]
# # INFORMACIÓN DEL PROYECTO

# %% [markdown]
# ### TÍTULO

# %% [markdown]
# # ¿Cómo viajan los turistas en España?

# %% [markdown]
# ### TEMA

# %% [markdown]
# Este proyecto analiza cómo ha evolucionado el turismo en España, estudiando los patrones de visitantes, sus motivos de viaje y las tipologías de turismo. A través de un análisis de datos detallado, buscamos entender las tendencias clave y descubrir historias detrás de los números, como la estacionalidad, la influencia del turismo de negocios o el impacto de eventos culturales. Un enfoque claro y accesible para quienes quieren explorar la riqueza del turismo español.

# %% [markdown]
# ### HIPÓTESIS

# %% [markdown]
# hipotesis_1 = ¿El turismo en España sigue una fuerte estacionalidad, con picos en verano y descensos en invierno?
#
# hipotesis_2 = ¿El turismo de ocio y recreo es el más predominante en España frente a otros motivos de viaje como negocios o estudios?
#
# hipotesis_3 = ¿El turismo de negocios se concentra en ciertas comunidades autónomas más que en otras?
#
# hipotesis_4 = ¿Los turistas de ciertos países gastan más dinero en España que otros?
#
# hipotesis_5 = ¿Algunas comunidades autónomas han experimentado un crecimiento más acelerado en el número de turistas que otras?

# %% [markdown]
# ## OBTENCIÓN DE LOS DATOS

# %% [markdown]
# ### DATASETS Y FUENTES ALTERNATIVAS DE DATOS

# %% [markdown]
# Incluye aquí una vista del dataset o datasets de los que partirás para poder evaluar tu hipótesis. <br>
# También incluye el origen de estos datos y su fuente.

# %%
import pandas as pd

#Viajeros y pernoctaciones por comunidades autónomas y provincias
df_1 = pd.read_csv("./src/data/datos_turismo.csv", delimiter=',')
fuente_1 = "https://www.ine.es/jaxiT3/Tabla.htm?t=2074"

#Número de visitantes según tipología
df_2 = pd.read_csv("./src/data/datos_tipologia.csv", delimiter=',')
fuente_2 = "https://www.ine.es/jaxiT3/Tabla.htm?t=10821"

#Número de turistas según motivo principal del viaje
df_3 = pd.read_csv("./src/data/datos_motivo.csv", delimiter=',')
fuente_3 = "https://www.ine.es/jaxiT3/Tabla.htm?t=13864"

# Gasto de los turistas internacionales según país de residencia
df_4 = pd.read_csv("./src/data/datos_gasto_pais.csv", delimiter=',')
fuente_4 = "https://www.ine.es/jaxiT3/Tabla.htm?t=10838"

# Gasto de los turistas internacionales según motivo principal del viaje
df_5 = pd.read_csv("./src/data/datos_sector.csv", delimiter=',')
fuente_5 = "https://www.ine.es/jaxiT3/Tabla.htm?t=23995"

# %% [markdown]
# Muestra mediante un head() los principales datasets con los que vas a trabajar

# %%
#Viajeros y pernoctaciones por comunidades autónomas y provincias
df_1.head()
# Out:
#   Unnamed: 0  01 Andalucía  04 Almería  11 Cádiz  14 Córdoba  18 Granada  \
# 0    2025M02     1210103.0     64254.0  127353.0     81664.0    220647.0
# 1    2025M01      983971.0     36982.0  100095.0     76019.0    188585.0
# 2    2024M12     1105005.0     48389.0  123395.0     80679.0    192332.0
# 3    2024M11     1278048.0     49231.0  140183.0     99847.0    208244.0
# 4    2024M10     1838241.0    101499.0  251255.0    110866.0    265193.0
#
#    21 Huelva  23 Jaén  29 Málaga  41 Sevilla  ...  31 Navarra  16 País Vasco  \
# 0    37989.0  39187.0   368010.0    270998.0  ...     55332.0       230365.0
# 1    22418.0  33075.0   269769.0    257029.0  ...     48807.0       206997.0
# 2    35037.0  41265.0   292539.0    291370.0  ...     67780.0       250596.0
# 3    47220.0  48020.0   369692.0    315609.0  ...     74629.0       278580.0
# 4    76257.0  58439.0   602997.0    371736.0  ...    100130.0       349844.0
#
# ...

# %%
#Número de visitantes según tipología
df_2.head()
# Out:
#                                          2025M01       2024M12       2024M11  \
# 0                          Dato base  8147788.00  8.779950e+06  9.053630e+06
# 1            Tasa de variación anual       12.47  2.670000e+00  1.234000e+01
# 2      Acumulado en lo que va de año  8147788.00  1.376401e+08  1.288602e+08
# 3        Tasa de variación acumulada       12.47  9.450000e+00  9.950000e+00
# 4                            Turista         NaN           NaN           NaN
#
#         2024M10       2024M09      2024M08      2024M07      2024M06  \
# 0  1.291969e+07  1.331016e+07  16621567.00  15957871.00  12483868.00
# 1  9.730000e+00  6.420000e+00         7.31         8.01         8.83
# 2  1.198065e+08  1.068868e+08  93576684.00  76955117.00  60997245.00
# 3  9.770000e+00  9.780000e+00        10.27        10.94        11.73
# 4           NaN           NaN          NaN          NaN          NaN
#
#        2024M05  ...      2016M07      2016M06      2016M05      2016M04  \
# ...

# %%
#Número de turistas según motivo principal del viaje
df_3.head()
# Out:
#                                          2025M01      2024M12      2024M11  \
# 0                          Dato base  5065094.00   5264375.00   5670219.00
# 1            Tasa de variación anual        6.06         1.06        10.41
# 2      Acumulado en lo que va de año  5065094.00  93759297.00  88494922.00
# 3        Tasa de variación acumulada        6.06        10.09        10.67
# 4          Ocio, recreo y vacaciones         NaN          NaN          NaN
#
#        2024M10      2024M09     2024M08      2024M07      2024M06  \
# 0   8961932.00   9602015.00  10929584.0  10852347.00   9299574.00
# 1         9.47         9.17         7.3         7.27        11.94
# 2  82824703.00  73862771.00  64260756.0  53331172.00  42478825.00
# 3        10.69        10.84        11.1        11.91        13.16
# 4          NaN          NaN         NaN          NaN          NaN
#
#        2024M05  ...      2016M07      2016M06      2016M05      2016M04  \
# ...

# %%
#Gasto de los turistas internacionales según país de residencia
df_4.head()
# Out:
#                       2025M01  2024M12  2024M11   2024M10   2024M09   2024M08  \
# 0        Gasto total      NaN      NaN      NaN       NaN       NaN       NaN
# 1              Total      NaN      NaN      NaN       NaN       NaN       NaN
# 2          Dato base  7132.04  7590.34  7707.67  11898.70  12613.05  15364.42
# 3        Reino Unido      NaN      NaN      NaN       NaN       NaN       NaN
# 4          Dato base  1096.09  1096.36  1156.75   2124.25   2451.03   3025.96
#
#     2024M07   2024M06   2024M05  ...   2016M07  2016M06  2016M05  2016M04  \
# 0       NaN       NaN       NaN  ...       NaN      NaN      NaN      NaN
# 1       NaN       NaN       NaN  ...       NaN      NaN      NaN      NaN
# 2  15513.29  12356.78  11686.91  ...  10238.54  7817.41  6917.93  5627.99
# 3       NaN       NaN       NaN  ...       NaN      NaN      NaN      NaN
# 4   2846.60   2481.75   2193.70  ...   2197.01  1766.61  1495.25  1153.23
#
# ...

# %%
#Gasto de los turistas internacionales según motivo principal del viaje
df_5.head()
# Out:
#                                                       2022(A)  2021(P)  \
# 0           A: Productos característicos del turismo  61483.7  24481.7
# 1                            1A: Hoteles y similares  17406.1   7168.6
# 2             1B: Servicios de alquiler inmobiliario   5797.7   2276.4
# 3   2: Servicios de provisión de alimentos y bebidas  10653.8   4419.1
# 4  3: Servicios de transporte de pasajeros por fe...    937.1    260.8
#
#       2020     2019     2018     2017     2016
# 0  15345.6  58853.0  56185.2  53153.9  47704.1
# 1   4004.6  19430.4  17852.3  15792.9  14177.2
# 2    764.9   5289.2   5124.4   5066.9   4277.1
# 3   2329.7  10380.1  10393.5  10054.5   9123.3
# 4    167.9    600.9    979.2   1045.4    874.9
